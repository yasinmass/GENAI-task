# %%
# !pip install tensorflow numpy pandas scikit-learn

# %%
import pandas as pd

data = {
    "text": [
        "Hello how are you",
        "I love machine learning",
        "Good morning everyone",
        "Bonjour comment ça va",
        "Je suis étudiant",
        "J'aime apprendre l'intelligence artificielle",
        "Hola cómo estás",
        "Me gusta aprender ciencia de datos",
        "Buenos días amigo",
        "Hallo wie geht es dir",
        "Ich liebe maschinelles Lernen",
        "Guten Morgen"
    ],
    "language": [
        "English","English","English",
        "French","French","French",
        "Spanish","Spanish","Spanish",
        "German","German","German"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                             text language
# 0                              Hello how are you  English
# 1                        I love machine learning  English
# 2                          Good morning everyone  English
# 3                          Bonjour comment ça va   French
# 4                               Je suis étudiant   French
# 5   J'aime apprendre l'intelligence artificielle   French
# 6                                Hola cómo estás  Spanish
# 7             Me gusta aprender ciencia de datos  Spanish
# 8                              Buenos días amigo  Spanish
# 9                          Hallo wie geht es dir   German
# 10                 Ich liebe maschinelles Lernen   German
# 11                                  Guten Morgen   German

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Encode labels
le = LabelEncoder()
df["label"] = le.fit_transform(df["language"])

# Tokenize text
tokenizer = Tokenizer(num_words=1000)
tokenizer.fit_on_texts(df["text"])
sequences = tokenizer.texts_to_sequences(df["text"])
X = pad_sequences(sequences, maxlen=10)

y = df["label"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Embedding, Flatten

input_layer = Input(shape=(10,))
embed = Embedding(1000, 64)(input_layer)
flat = Flatten()(embed)

encoded = Dense(32, activation="relu")(flat)
decoded = Dense(64, activation="relu")(encoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer="adam", loss="mse")

autoencoder.fit(X_train, embed.numpy() if hasattr(embed, "numpy") else autoencoder.predict(X_train),
                epochs=10, verbose=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step - loss: 4.9381e-18
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 6.0215e-16
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.3238e-13
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 5.6917e-10
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.6224e-07
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.4334e-06
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.9614e-06
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.2823e-06
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 8.6967e-07
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 4.1432e-06

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

lstm_model = Sequential([
    Embedding(1000, 64, input_length=10),
    LSTM(64),
    Dense(len(le.classes_), activation="softmax")
])

lstm_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

lstm_model.fit(X_train, y_train, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4444 - loss: 1.3871
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7778 - loss: 1.3789
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6667 - loss: 1.3707
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6667 - loss: 1.3626
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6667 - loss: 1.3543
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6667 - loss: 1.3457
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6667 - loss: 1.3368
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6667 - loss: 1.3274
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6667 - loss: 1.3175
# Epoch 10/20
# ...

# %%
loss, acc = lstm_model.evaluate(X_test, y_test)
print("LSTM Accuracy:", acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.0000e+00 - loss: 2.0062
# LSTM Accuracy: 0.0

# %%
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization

inputs = Input(shape=(10,))
x = Embedding(1000, 64)(inputs)

attn = MultiHeadAttention(num_heads=2, key_dim=64)(x, x)
x = LayerNormalization()(x + attn)

x = Flatten()(x)
outputs = Dense(len(le.classes_), activation="softmax")(x)

transformer_model = Model(inputs, outputs)

transformer_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

transformer_model.fit(X_train, y_train, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4444 - loss: 1.5369
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5556 - loss: 1.0553
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5556 - loss: 0.9056
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7778 - loss: 0.6797
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.4845
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.3628
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.2800
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.2194
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.1711
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1296
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0958
# Epoch 12/20
# ...

# %%
loss, acc = transformer_model.evaluate(X_test, y_test)
print("Transformer Accuracy:", acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.0000e+00 - loss: 2.5339
# Transformer Accuracy: 0.0

# %% [markdown]
# def predict_language(text):
#     seq = tokenizer.texts_to_sequences([text])
#     padded = pad_sequences(seq, maxlen=10)
#     pred = lstm_model.predict(padded)
#     return le.inverse_transform([pred.argmax()])[0]
#
# predict_language("Guten Abend mein Freund")

# %%
# !pip install gtts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
# ...

# %%
from gtts import gTTS
from IPython.display import Audio, display

# %%
text = "Hello, welcome to text to speech conversion using Google Colab."

tts = gTTS(text=text, lang="en")
tts.save("output_audio.mp3")

# %%
display(Audio("output_audio.mp3", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import files
files.download("output_audio.mp3")

# %%
text = "Bonjour tout le monde"
tts = gTTS(text=text, lang="fr")   # fr = French
tts.save("french_audio.mp3")
display(Audio("french_audio.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def text_to_audio(text, lang="en", filename="speech.mp3"):
    tts = gTTS(text=text, lang=lang)
    tts.save(filename)
    display(Audio(filename))

# %%
text_to_audio("This is a complete text to speech system", "en")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
